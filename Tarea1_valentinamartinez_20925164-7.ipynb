# %% [markdown]
# # Tarea 1.10
# valentina martinez 20925164-7
#
# Un colega le pasa a usted un archivo .hd5 que contiene tres "datasets" 'x', 'y', 'e'. Todos los datasets tienen la misma longitud y el i-ésimo elemento de cada dataset corresponde a una propiedad diferente del i-ésimo dato.
#
# Escriba una función que grafique esos resultados donde 'x' es el eje horizontal, 'y' el eje vertical y 'e' son las barras de error de 'y'.

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
#Definimos datos
def datasets(x, y, e): 
    with h5py.File(archivo_hd5, 'r') as archivo:
        # Cargar los datasets 'x', 'y' y 'e'
        x = archivo['x'][:]
        y = archivo['y'][:]
        e = archivo['e'][:]

# %%
#graficamos los datasets y cambiamos de color las barras de error

plt.errorbar(x, y, e, ecolor='pink')
    
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafica de los datos con barras de error')
    
plt.show()

# %% [markdown]
# # Nota: 70
